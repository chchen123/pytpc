# %%
# %matplotlib inline
import numpy
import numpy.matlib as mat
import scipy.constants
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from numpy import sin, cos, tan, sqrt, log
from scipy.stats import threshold
import math

import kalman
import tracking
from constants import *

import copy

# %% [markdown]
# ## Actual values

# %%
pt = tracking.Particle(mass_num=4, charge_num=2, energy_per_particle=2, azimuth=pi/3, polar=pi/9)
efield = [0, 0, 15e3]
bfield = [0, 0, -1]
g = tracking.Gas(4, 2, 41.8, 150.)

# %%
pos, azi, pol, time, en = map(numpy.array, tracking.track(pt, g, efield, bfield))
# Out:
# Particle left chamber

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(pos[:,0], pos[:,1], pos[:,2])

# %%
plt.plot(en)

# %%
xyfig = plt.figure()
xyax = xyfig.add_subplot(111)
xyax.plot(pos[:,0], pos[:,1])
xyax.set_aspect('equal')

# %% [markdown]
# # Finding the State Vectors

# %%
sv, ctr = tracking.find_state_vector(pos)

# %%
def state_vector_plots(sv, sv2=None, data=None):
    fig, ax = plt.subplots(3, 2, sharex=True)
    fig.set_figheight(15)
    fig.set_figwidth(15)
    
    ax[0,0].plot(sv[:,-1], sv[:,0], label='Actual', zorder=2)
    ax[0,1].plot(sv[:,-1], sv[:,1], label='Actual', zorder=2)
    ax[1,0].plot(sv[:,-1], sv[:,2], label='Actual', zorder=2)
    ax[1,1].plot(sv[:,-1], sv[:,3], label='Actual', zorder=2)
    ax[2,0].plot(sv[:,-1], sv[:,4], label='Actual', zorder=2)
    ax[2,1].plot(sv[:,-1], sv[:,5], label='Actual', zorder=2)
    
    if sv2 is not None:
        ax[0,0].plot(sv2[:,-1], sv2[:,0], label='Calculated', zorder=3)
        ax[0,1].plot(sv2[:,-1], sv2[:,1], label='Calculated', zorder=3)
        ax[1,0].plot(sv2[:,-1], sv2[:,2], label='Calculated', zorder=3)
        ax[1,1].plot(sv2[:,-1], sv2[:,3], label='Calculated', zorder=3)
        ax[2,0].plot(sv2[:,-1], sv2[:,4], label='Calculated', zorder=3)
        ax[2,1].plot(sv2[:,-1], sv2[:,5], label='Calculated', zorder=3)
        
    if data is not None:
        ax[0,0].plot(sv[:,-1], data[:,0], '+', label='Data', zorder=1)
        ax[0,1].plot(sv[:,-1], data[:,1], '+', label='Data', zorder=1)
        ax[1,0].plot(sv[:,-1], data[:,2], '+', label='Data', zorder=1)
        ax[1,1].plot(data[:,-1], data[:,3], '+', label='Data', zorder=1)
        ax[2,0].plot(data[:,-1], data[:,4], '+', label='Data', zorder=1)
        ax[2,1].plot(data[:,-1], data[:,5], '+', label='Data', zorder=1)
    
    ax[0,0].set_ylabel('x [m]')
    ax[0,0].legend(loc='best')
    
    ax[0,1].set_ylabel('y [m]')
    ax[0,1].legend(loc='best')
    
    ax[1,0].set_ylabel('z [m]')
    ax[1,0].legend(loc='best')
    
    ax[1,1].set_ylabel('Inverse Radius of Curvature [$m^{-1}$]')
    ax[1,1].legend(loc='best')
    
    ax[2,0].set_ylabel('Pitch angle $\lambda$')
    ax[2,0].legend(loc='best')
    
    ax[2,1].set_ylabel('Azimuthal angle $\phi$')
    ax[2,1].legend(loc='best')

# %%
state_vector_plots(sv)

# %% [markdown]
# # Extended Kalman filter

# %%
test = numpy.zeros((sv.shape[0],6))
test[0] = sv[1]
for x in range(1, sv.shape[0]):
    test[x] = tracking.update_state_vector(test[x-1])
state_vector_plots(sv[1:], test[1:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8da46ce8cafe> in <module>()
#       2 test[0] = sv[1]
#       3 for x in range(1, sv.shape[0]):
# ----> 4     test[x] = tracking.update_state_vector(test[x-1])
#       5 state_vector_plots(sv[1:], test[1:])
#
# AttributeError: 'module' object has no attribute 'update_state_vector'

# %%
meas = pos + numpy.random.normal(0, 1e-2, pos.shape)

# %%
tr = tracking.Tracker(pt, g, efield, bfield)
kf = tr.track(meas)

# %%
tracking.find_state_vector(meas)
# Out:
# (array([[ -1.05324291e-02,  -3.08510124e-03,  -6.39065871e-03,
#            1.31285893e+02,   0.00000000e+00,  -5.83638895e-01],
#         [ -5.59058742e-03,  -1.54708561e-02,   2.78923691e-03,
#            1.31285893e+02,   6.02893850e-01,  -6.45198389e-01],
#         [ -4.56834990e-03,  -2.96674684e-04,   1.22761201e-02,
#            4.01290610e+01,   5.57725237e-01,  -5.35281045e-01],
#         ...,
#         [ -2.00520618e-01,   1.66857723e-01,   9.94724019e-01,
#            9.24998134e+01,  -2.97513686e-01,   2.29816231e+00],
#         [ -1.87016844e-01,   1.60090536e-01,   1.00754240e+00,
#            7.76405797e+01,   7.03706925e-01,   2.25536193e+00],
#         [ -2.05141870e-01,   1.65147307e-01,   9.80335902e-01,
#            7.76405797e+01,  -9.65700441e-01,   2.32952326e+00]]),
#  array([-0.1044515 ,  0.05893734]))

# %%
state_vector_plots(sv, kf.xhat, data=tracking.find_state_vector(meas)[0])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', axisbg='w')
ax.plot(meas[:,0], meas[:,1], meas[:,2], '.')
ax.plot(pos[:,0], pos[:,1], pos[:,2])
ax.plot(xhat[:,0], xhat[:,1], xhat[:,2], '-')

# %%
state_vector_plots_compare(sv[1:], data=sv_meas[1:])

# %%
numpy.std(sv_meas - sv, 0)
# Out:
# array([  9.97255372e-03,   9.93935473e-03,   1.00333641e-02,
#          5.12052116e+01,   6.76593953e-01,   2.09259490e-01])
