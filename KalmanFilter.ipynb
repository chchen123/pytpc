# %%
# %matplotlib inline
import numpy
import numpy.matlib as mat
import scipy.constants
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from numpy import sin, cos, tan, sqrt, log
from scipy.stats import threshold
from scipy.signal import savgol_filter
import math

import kalman
import tracking
from constants import *

import copy

# %% [markdown]
# ## Actual values

# %%
pt = tracking.Particle(mass_num=4, charge_num=2, energy_per_particle=2, azimuth=pi/3, polar=pi/9)
efield = [0, 0, 15e3]
bfield = [0, 0, -1]
g = tracking.Gas(4, 2, 41.8, 150.)

# %%
pos, mom, time, en = map(numpy.array, tracking.track(pt, g, efield, bfield))
# Out:
# Particle left chamber

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(pos[:,0], pos[:,1], pos[:,2])

# %%
plt.plot(en)

# %%
xyfig = plt.figure()
xyax = xyfig.add_subplot(111)
xyax.plot(pos[:,0], pos[:,1])
xyax.set_aspect('equal')

# %% [markdown]
# # Finding the State Vectors

# %%
sv = numpy.hstack((pos, mom))

# %%
def state_vector_plots(sv, sv2=None, data=None):
    fig, ax = plt.subplots(3, 2)
    fig.set_figheight(15)
    fig.set_figwidth(15)
    
    ax[0,0].plot(sv[:,0], label='Actual', zorder=2)
    ax[1,0].plot(sv[:,1], label='Actual', zorder=2)
    ax[2,0].plot(sv[:,2], label='Actual', zorder=2)
    ax[0,1].plot(sv[:,3], label='Actual', zorder=2)
    ax[1,1].plot(sv[:,4], label='Actual', zorder=2)
    ax[2,1].plot(sv[:,5], label='Actual', zorder=2)
    
    if sv2 is not None:
        ax[0,0].plot(sv2[:,0], label='Calculated', zorder=3)
        ax[1,0].plot(sv2[:,1], label='Calculated', zorder=3)
        ax[2,0].plot(sv2[:,2], label='Calculated', zorder=3)
        ax[0,1].plot(sv2[:,3], label='Calculated', zorder=3)
        ax[1,1].plot(sv2[:,4], label='Calculated', zorder=3)
        ax[2,1].plot(sv2[:,5], label='Calculated', zorder=3)
        
    if data is not None:
        ax[0,0].plot(data[:,0], '+', label='Data', zorder=1)
        ax[1,0].plot(data[:,1], '+', label='Data', zorder=1)
        ax[2,0].plot(data[:,2], '+', label='Data', zorder=1)
        ax[0,1].plot(data[:,3], '+', label='Data', zorder=1)
        ax[1,1].plot(data[:,4], '+', label='Data', zorder=1)
        ax[2,1].plot(data[:,5], '+', label='Data', zorder=1)
    
    ax[0,0].set_ylabel('x [m]')
    ax[0,0].legend(loc='best')
    
    ax[1,0].set_ylabel('y [m]')
    ax[1,0].legend(loc='best')
    
    ax[2,0].set_ylabel('z [m]')
    ax[2,0].legend(loc='best')
    
    ax[0,1].set_ylabel('px [kg m/s]')
    ax[0,1].legend(loc='best')
    
    ax[1,1].set_ylabel('py [kg m/s]')
    ax[1,1].legend(loc='best')
    
    ax[2,1].set_ylabel('pz [kg m/s]')
    ax[2,1].legend(loc='best')

# %%
state_vector_plots(sv)

# %% [markdown]
# # Extended Kalman filter

# %%
test = numpy.zeros((sv.shape[0],6))
test[0] = sv[0]
test_tracker = tracking.Tracker(tracking.Particle(4, 2), g, efield, bfield)
for x in range(1, sv.shape[0]):
    test[x] = test_tracker.update_state_vector(test[x-1])
state_vector_plots(sv, test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ca997883747b> in <module>()
#       1 test = numpy.zeros((sv.shape[0],6))
#       2 test[0] = sv[0]
# ----> 3 test_tracker = tracking.Tracker(tracking.Particle(4, 2), g, efield, bfield)
#       4 for x in range(1, sv.shape[0]):
#       5     test[x] = test_tracker.update_state_vector(test[x-1])
#
# TypeError: __init__() missing 1 required positional argument: 'seed'

# %%
meas_pos = pos + numpy.random.normal(0, 1e-2, pos.shape)
sm = savgol_filter(meas_pos, 201, 2, axis=0)
dfs = numpy.diff(sm, axis=0)
meas = numpy.hstack((meas_pos[1:], dfs))

# %%
test_sv = numpy.array([test_tracker.generate_measurement(v) for v in sv])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7a819271e252> in <module>()
# ----> 1 test_sv = numpy.array([test_tracker.generate_measurement(v) for v in sv])
#
# <ipython-input-9-7a819271e252> in <listcomp>(.0)
# ----> 1 test_sv = numpy.array([test_tracker.generate_measurement(v) for v in sv])
#
# NameError: name 'test_tracker' is not defined

# %%
state_vector_plots(test_sv, data=meas)

# %%
tr = tracking.Tracker(pt, g, efield, bfield, seed=sv[0])
tr.kfilter.q_mat = numpy.diag((1e-6, 1e-6, 1e-6, 1e-21, 1e-21, 1e-21))
tr.kfilter.r_mat = numpy.diag((1e-2, 1e-2, 1e-2, 1e-4, 1e-4, 1e-4))
kf = tr.track(meas)
# Out:
# [  1.70260798e-04   2.96576499e-04   9.39565474e-04   2.23094492e-20
#    3.88607266e-20   1.23112240e-19]
# [  1.88371355e-01  -1.62920453e-01  -6.91450853e-03  -3.54431780e-20
#    1.20903429e-19   1.36187116e-19]
# [-0.55245941  1.05737054  0.00333708 -0.         -0.          0.        ]
# /Users/josh/Documents/Code/pytpc/tracking.py:287: RuntimeWarning: invalid value encountered in double_scalars
#   [0, 0, 0, -((pos_step*px**2)/(px**2 + py**2 + pz**2)**(3/2))
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-80cb3d87e15b> in <module>()
#       2 tr.kfilter.q_mat = numpy.diag((1e-6, 1e-6, 1e-6, 1e-21, 1e-21, 1e-21))
#       3 tr.kfilter.r_mat = numpy.diag((1e-2, 1e-2, 1e-2, 1e-4, 1e-4, 1e-4))
# ----> 4 kf = tr.track(meas)
#
# /Users/josh/Documents/Code/pytpc/tracking.py in track(self, meas)
#     296
#     297     def track(self, meas):
# --> 298         self.kfilter.apply(meas)
#     299         return self.kfilter
#     300
#
# /Users/josh/Documents/Code/pytpc/kalman.py in apply(self, z)
#      96
#      97                 # measurement update step
# ---> 98                 h_mat = self.measure_jacobian(self.xhatminus[k])
#      99                 h_mat_t = h_mat.T
#     100
#
# /Users/josh/Documents/Code/pytpc/tracking.py in measure_jacobian(state)
#     286                             [0, 0, 1, 0, 0, 0],
#     287                             [0, 0, 0, -((pos_step*px**2)/(px**2 + py**2 + pz**2)**(3/2))
# --> 288                              + pos_step/sqrt(px**2 + py**2 + pz**2), -((pos_step*px*py)/(px**2 + py**2 + pz**2)**(3/2)),
#     289                              -((pos_step*px*pz)/(px**2 + py**2 + pz**2)**(3/2))],
#     290                             [0, 0, 0, -((pos_step*px*py)/(px**2 + py**2 + pz**2)**(3/2)),
#
# ZeroDivisionError: float division by zero

# %%
tr.kfilter.xhat[0:6]
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           2.24076879e-20,   3.88112539e-20,   1.23129233e-19],
#        [  1.88562387e-01,  -1.63572099e-01,  -7.64853064e-03,
#          -3.52348168e-20,   1.20969505e-19,   1.36192532e-19],
#        [ -5.52459413e-01,   1.05737054e+00,   3.33708478e-03,
#          -1.94633694e-19,  -1.56718268e-19,   1.36186921e-19],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
tr.update_state_vector(tr.kfilter.xhat[0])
# Out:
# array([  1.70260798e-04,   2.96576499e-04,   9.39565474e-04,
#          2.23094492e-20,   3.88607266e-20,   1.23112240e-19])

# %%
tr.kfilter.update_jacobian(tr.kfilter.xhatminus[1])
# Out:
# array([[  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.49465948e+26,   0.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.49465948e+26,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.49465948e+26],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,  -4.78941679e+07,  -0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           4.78941679e+07,   1.00000000e+00,   0.00000000e+00],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,  -0.00000000e+00,   1.00000000e+00]])

# %%
tr.kfilter.p_mat_minus
# Out:
# array([[[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]],
#
#        [[  2.23400697e+22,   0.00000000e+00,   0.00000000e+00,
#            1.49465948e-04,   7.15854723e+03,   0.00000000e+00],
#         [  0.00000000e+00,   2.23400697e+22,   0.00000000e+00,
#           -7.15854723e+03,   1.49465948e-04,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   2.23400697e+22,
#            0.00000000e+00,   0.00000000e+00,   1.49465948e-04],
#         [  1.49465948e-04,  -7.15854723e+03,   0.00000000e+00,
#            2.29385232e-15,   0.00000000e+00,   0.00000000e+00],
#         [  7.15854723e+03,   1.49465948e-04,   0.00000000e+00,
#            0.00000000e+00,   2.29385232e-15,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   1.49465948e-04,
#            0.00000000e+00,   0.00000000e+00,   1.00000000e-21]],
#
#        [[  3.12864690e+37,   1.52181435e+36,   8.93716535e+29,
#           -4.87643058e+17,   1.00252895e+19,   5.97939897e+03],
#         [  5.01564838e+37,   8.15625280e+36,   1.14212772e+30,
#           -2.61355142e+18,   1.60719086e+19,   7.64139084e+03],
#         [  1.27413305e+31,   1.13334953e+31,   1.97267719e+31,
#           -3.63165209e+12,   4.08277226e+12,   1.31981713e+05],
#         [ -1.60719086e+19,  -2.61355142e+18,  -3.65978030e+11,
#            8.37474167e-01,  -5.15000706e+00,  -2.44857130e-15],
#         [  1.00252895e+19,   4.87643058e+17,   2.86378379e+11,
#           -1.56258056e-01,   3.21245678e+00,   1.91601086e-15],
#         [  8.52457072e+04,   7.58266041e+04,   1.31981713e+05,
#           -2.42975215e-14,   2.73157352e-14,   1.88302195e-21]],
#
#        ...,
#        [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]],
#
#        [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]],
#
#        [[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]]])

# %%
state_vector_plots(sv, tr.kfilter.xhat, data=meas)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d', axisbg='w')
ax.plot(meas[:,0], meas[:,1], meas[:,2], '.')
ax.plot(pos[:,0], pos[:,1], pos[:,2])
ax.plot(xhat[:,0], xhat[:,1], xhat[:,2], '-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b4a270827ab7> in <module>()
#       3 ax.plot(meas[:,0], meas[:,1], meas[:,2], '.')
#       4 ax.plot(pos[:,0], pos[:,1], pos[:,2])
# ----> 5 ax.plot(xhat[:,0], xhat[:,1], xhat[:,2], '-')
#
# NameError: name 'xhat' is not defined

# %%
plt.plot(numpy.diff(meas, axis=0), '.', alpha=0.8)

# %%
plt.plot(meas[:,0])

# %%
from scipy.signal import savgol_filter

# %%
sm = savgol_filter(meas, 201, 2, axis=0)
dfs = numpy.diff(sm, axis=0)

# %%
plt.plot(dfs, '.', alpha=0.5)
plt.legend(('x', 'y', 'z'))

# %%
plt.plot(mom / (4 * p_kg))
# Out:
# [<matplotlib.lines.Line2D at 0x114517588>,
#  <matplotlib.lines.Line2D at 0x114517908>,
#  <matplotlib.lines.Line2D at 0x114517be0>]
