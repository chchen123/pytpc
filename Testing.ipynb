# %% [markdown]
# # Testing notebook

# %% [markdown]
# ## Imports

# %%
import pyevt
import attpc
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy
import scipy.stats as ss
import timeit

# %%
ef = pyevt.EventFile("/Users/josh/Documents/Data/run_0016.evt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8b3dbdd417f7> in <module>()
# ----> 1 ef = pyevt.EventFile("/Users/josh/Documents/Data/run_0016.evt")
#
# NameError: name 'pyevt' is not defined

# %%
# %timeit ef.read_next_new()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9296dddfd91e> in <module>()
# ----> 1 get_ipython().magic('timeit ef.read_next_new()')
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
#    2127             return result
#    2128
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1011             number = 1
#    1012             for _ in range(1, 10):
# -> 1013                 if timer.timeit(number) >= 0.2:
#    1014                     break
#    1015                 number *= 10
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/timeit.py in timeit(self, number)
#     176         gc.disable()
#     177         try:
# --> 178             timing = self.inner(it, self.timer)
#     179         finally:
#     180             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# NameError: name 'ef' is not defined

# %%
evt = ef.read_next_new()
# Out:
# Found event of size 14247955 :
#     Event Number: 0
#     Contains 9216 traces

# %%
peds = pyevt.load_pedestals("/Users/josh/Dropbox/routing/Peds20141208-2.csv")

# %%
evt.traces = ss.threshold(evt.traces - peds, threshmin=10)

# %%
pm = pyevt.load_padmap("/Users/josh/Dropbox/routing/Lookup20141208.csv")
hits = evt.hits(pm)

# %%
attpc.pad_plot(hits)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.plot(evt.traces.sum((1,2,3,4)))
plt.show()

# %%
pads = attpc.generate_pad_plane()

# %%
plt.scatter(pads[...,0], pads[...,1],marker='.')

# %%
pk = pyevt.EventFile().pack_sample
up = pyevt.EventFile().unpack_sample
ups = pyevt.EventFile().unpack_samples

# %%
a = numpy.array([pk(*x) for x in list(zip(range(0,512),range(256,256+512)))])

# %%
def doit(a):
    final = numpy.zeros(512)
    for x in a:
        z = up(x)
        final[z[0]] = z[1]
    return final

# %%
# %timeit doit(a)
# Out:
# 1000 loops, best of 3: 633 µs per loop

# %%
# %timeit ups(a)
# Out:
# 10000 loops, best of 3: 183 µs per loop

# %%
num = pk(251,591)

# %%
b = num.to_bytes(3,'little')

# %%
i = int.from_bytes(b,'little')

# %%
up(i)
# Out:
# (251, 591)
