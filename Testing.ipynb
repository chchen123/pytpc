# %% [markdown]
# # Testing notebook

# %% [markdown]
# ## Imports

# %%
# %matplotlib osx
import evtdata
import tpcplot
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy
import scipy.stats as ss
import timeit

# %%
ef = evtdata.EventFile("/Users/josh/Documents/Data/Alphas-Dec14/run_0225.evt")
# Out:
# Opened file: /Users/josh/Documents/Data/Alphas-Dec14/run_0225.evt

# %%
peds = evtdata.load_pedestals("/Users/josh/Dropbox/routing/Peds20141208-2.csv")

# %%
pm = evtdata.load_padmap("/Users/josh/Dropbox/routing/Lookup20141208.csv")

# %%
evt = ef.read_event_by_number(10)
evt.traces = ss.threshold(evt.traces - peds, threshmin=40)
# Out:
# Found event of size 182447 :
#     Event Number: 10
#     Contains 118 traces
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py:1094: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.button_pressed in self._rotate_btn:

# %%
p = tpcplot.pad_plot(evt.hits(pm))

# %%
tpcplot.chamber_plot(evt.xyzs(pm))

# %%
mesh = evt.traces.sum((0,1,2,3))
plt.plot(mesh, 'b-')
plt.xlabel('Time Bucket')
plt.ylabel('Activation')
plt.axis('tight')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py:1094: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.button_pressed in self._rotate_btn:
# (0.0, 511.0, 0.0, 2202.0)

# %%
lines = evt.traces.reshape((10880, 512))
fig, ax = plt.subplots()
for l in lines:
    ax.plot(l)

# %%
lines = evt.traces.reshape((10880, 512))

# %%
plt.plot(lines[17])

# %%
f = plt.figure()
f.add_subplot(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-19d52bfa03b4> in <module>()
#       1 f = plt.figure()
# ----> 2 f.add_subplot(p)
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     956                     self._axstack.remove(ax)
#     957
# --> 958             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     959
#     960         self._axstack.add(key, a)
#
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      43             else:
#      44                 try:
# ---> 45                     s = str(int(args[0]))
#      46                     rows, cols, num = list(map(int, s))
#      47                 except ValueError:
#
# TypeError: int() argument must be a string or a number, not 'Figure'
